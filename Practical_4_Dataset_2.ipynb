# %% [markdown]
# ## PRACTICAL:- 4_180280116040_Dharmistha_Kosti

# %% [markdown]
# #### Exploring Pandas Library  to perform  Various Tasks for Data Handling, Wrangling , Cleaning, Description, Arrangement   on selected second dataset.

# %%
# importing csv file
import pandas as pd
df = pd.read_csv(r'C:\Users\HP\Downloads\dataset\MELBOURNE_HOUSE_PRICES_LESS.csv')
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# ...

# %%
df.head(5)
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
df.tail(5)
# Out:
#                  Suburb         Address  Rooms Type     Price Method SellerG  \
# 63018     Roxburgh Park       3 Carr Pl      3    h  566000.0      S   Raine
# 63019     Roxburgh Park     9 Parker Ct      3    h  500000.0      S   Raine
# 63020     Roxburgh Park  5 Parkinson Wy      3    h  545000.0      S   Raine
# 63021        Thomastown  3/1 Travers St      3    u       NaN     PI   Barry
# 63022  Williams Landing     1 Diadem Wy      4    h       NaN     SP  Aussie
#
#              Date  Postcode             Regionname  Propertycount  Distance  \
# 63018  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63019  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63020  31/03/2018      3064  Northern Metropolitan           5833      20.6
# 63021  31/03/2018      3074  Northern Metropolitan           7955      15.3
# 63022  31/03/2018      3027   Western Metropolitan           1999      17.6
#
#                    CouncilArea
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Postcode  Propertycount      Distance
# count  63023.000000  4.843300e+04  63023.000000   63023.000000  63023.000000
# mean       3.110595  9.978982e+05   3125.673897    7617.728131     12.684829
# std        0.957551  5.934989e+05    125.626877    4424.423167      7.592015
# min        1.000000  8.500000e+04   3000.000000      39.000000      0.000000
# 25%        3.000000  6.200000e+05   3056.000000    4380.000000      7.000000
# 50%        3.000000  8.300000e+05   3107.000000    6795.000000     11.400000
# 75%        4.000000  1.220000e+06   3163.000000   10412.000000     16.700000
# max       31.000000  1.120000e+07   3980.000000   21650.000000     64.100000

# %%
pd.set_option('max_colwidth', 800)

# %% [markdown]
# This particular statement sets max width to 800px, per column.

# %%
df.rename(columns={'Suburb':'Sub','CouncilArea':'CA','Address':'Add','Propertycount':'Pc'},inplace=True)
df.head()
# Out:
#             Sub               Add  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname    Pc  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan  4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan  4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan  4019       3.0
# 3  1/04/2017      3040   Western Metropolitan  1543       7.5
# 4  1/04/2017      3042   Western Metropolitan  3464      10.4
#
#                            CA
# 0          Yarra City Council
# 1          Yarra City Council
# 2          Yarra City Council
# ...

# %%
average = df['Price'].mean()
print("Average of House Price:-", average)

med = df['Price'].median()
print("Median of House Price:-", med)

standard_deviation = df['Price'].std()
print("Standard Deviation of House Price:-", standard_deviation)
# Out:
# Average of House Price:- 997898.2414882415
# Median of House Price:- 830000.0
# Standard Deviation of House Price:- 593498.9190372798

# %%
df.shape
# Out:
# (63023, 13)

# %%
df.columns
# Out:
# Index(['Sub', 'Add', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date',
#        'Postcode', 'Regionname', 'Pc', 'Distance', 'CA'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Sub            object
# Add            object
# Rooms           int64
# Type           object
# Price         float64
# Method         object
# SellerG        object
# Date           object
# Postcode        int64
# Regionname     object
# Pc              int64
# Distance      float64
# CA             object
# dtype: object

# %%
data=df[['Rooms','Type','Price','Method','SellerG','Date','Postcode']]
data.head()
# Out:
#    Rooms Type      Price Method   SellerG       Date  Postcode
# 0      3    h  1490000.0      S    Jellis  1/04/2017      3067
# 1      3    h  1220000.0      S  Marshall  1/04/2017      3067
# 2      3    h  1420000.0      S    Nelson  1/04/2017      3067
# 3      3    h  1515000.0      S     Barry  1/04/2017      3040
# 4      2    h   670000.0      S    Nelson  1/04/2017      3042

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63023 entries, 0 to 63022
# Data columns (total 13 columns):
# Sub           63023 non-null object
# Add           63023 non-null object
# Rooms         63023 non-null int64
# Type          63023 non-null object
# Price         48433 non-null float64
# Method        63023 non-null object
# SellerG       63023 non-null object
# Date          63023 non-null object
# Postcode      63023 non-null int64
# Regionname    63023 non-null object
# Pc            63023 non-null int64
# Distance      63023 non-null float64
# CA            63023 non-null object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 6.3+ MB

# %%
df['Distance'].nunique()
# Out:
# 180

# %%
df.sort_values("Price",axis=0,ascending=True,inplace=True)
df.head()
# Out:
#                 Sub                  Add  Rooms Type     Price Method  \
# 4100      Footscray     202/51 Gordon St      1    u   85000.0     PI
# 8867   Malvern East  114/141 Waverley Rd      1    u  112000.0      S
# 31660  Malvern East  114/141 Waverley Rd      1    u  112000.0      S
# 13611  Malvern East  114/141 Waverley Rd      1    u  112000.0      S
# 46453  Malvern East  114/141 Waverley Rd      1    u  112000.0      S
#
#        SellerG        Date  Postcode             Regionname    Pc  Distance  \
# 4100   Burnham   3/09/2016      3011   Western Metropolitan  7570       5.1
# 8867       C21   6/01/2018      3145  Southern Metropolitan  8801       8.4
# 31660      C21  16/12/2017      3145  Southern Metropolitan  8801       8.4
# 13611      C21   8/01/2018      3145  Southern Metropolitan  8801       8.4
# 46453      C21  23/12/2017      3145  Southern Metropolitan  8801       8.4
#
#                              CA
# 4100   Maribyrnong City Council
# ...

# %%
df.isna().head()
# Out:
#          Sub    Add  Rooms   Type  Price  Method  SellerG   Date  Postcode  \
# 4100   False  False  False  False  False   False    False  False     False
# 8867   False  False  False  False  False   False    False  False     False
# 31660  False  False  False  False  False   False    False  False     False
# 13611  False  False  False  False  False   False    False  False     False
# 46453  False  False  False  False  False   False    False  False     False
#
#        Regionname     Pc  Distance     CA
# 4100        False  False     False  False
# 8867        False  False     False  False
# 31660       False  False     False  False
# 13611       False  False     False  False
# 46453       False  False     False  False

# %%
df.isna().sum()
# Out:
# Sub               0
# Add               0
# Rooms             0
# Type              0
# Price         14590
# Method            0
# SellerG           0
# Date              0
# Postcode          0
# Regionname        0
# Pc                0
# Distance          0
# CA                0
# dtype: int64

# %%
df.empty
# Out:
# False

# %%
df.memory_usage()
# Out:
# Index         504184
# Sub           504184
# Add           504184
# Rooms         504184
# Type          504184
# Price         504184
# Method        504184
# SellerG       504184
# Date          504184
# Postcode      504184
# Regionname    504184
# Pc            504184
# Distance      504184
# CA            504184
# dtype: int64

# %% [markdown]
# Return the memory usage of each column in bytes.

# %%
df.memory_usage(deep=True)
# Out:
# Index          504184
# Sub           4216679
# Add           4442189
# Rooms          504184
# Type          3907426
# Price          504184
# Method        3821998
# SellerG       3982303
# Date          4204478
# Postcode       504184
# Regionname    4913507
# Pc             504184
# Distance       504184
# CA            4950817
# dtype: int64

# %%
data2=df[['Price','Pc']]
gr=data2.groupby(['Price'],as_index=False).mean()
gr.head()
# Out:
#       Price      Pc
# 0   85000.0  7570.0
# 1  112000.0  8801.0
# 2  121000.0  3040.0
# 3  131000.0  2379.0
# 4  132500.0  4794.0

# %%
df['Price'].value_counts()
# Out:
# 600000.0     459
# 1100000.0    432
# 1000000.0    396
# 800000.0     396
# 750000.0     388
#             ...
# 2301000.0      1
# 3510000.0      1
# 1412500.0      1
# 2361000.0      1
# 2465000.0      1
# Name: Price, Length: 3417, dtype: int64

# %%
df["SellerG"].value_counts()
# Out:
# Barry                 6894
# Jellis                5499
# Nelson                4739
# Ray                   4554
# hockingstuart         4332
#                       ...
# Vic                      1
# hockingstuart/Kerr       1
# Christou                 1
# VicBrokers               1
# Flanagan                 1
# Name: SellerG, Length: 476, dtype: int64

# %%
df["Sub"].value_counts()
# Out:
# Reservoir           1241
# Bentleigh East       845
# Mount Waverley       831
# Richmond             822
# Glen Waverley        819
#                     ...
# Belgrave Heights       1
# Wildwood               1
# Wandin North           1
# Guys Hill              1
# Menzies Creek          1
# Name: Sub, Length: 380, dtype: int64

# %%
print(pd.pivot_table(df,index=['Price']))
# Out:
#             Distance       Pc  Postcode  Rooms
# Price
# 85000.0          5.1   7570.0    3011.0    1.0
# 112000.0         8.4   8801.0    3145.0    1.0
# 121000.0         1.3   3040.0    3002.0    1.0
# 131000.0         8.7   2379.0    3162.0    4.0
# 132500.0        16.0   4794.0    3190.0    4.0
# ...              ...      ...       ...    ...
# 7000000.0        6.3   4836.0    3143.0    4.0
# 7650000.0        5.3  11308.0    3122.0    4.0
# 8000000.0        8.4   3265.0    3126.0    5.0
# 9000000.0       18.8   7113.0    3170.0    3.0
# 11200000.0      10.5  10579.0    3186.0    4.0
#
# [3417 rows x 4 columns]

# %%
Price_gt=df.where(df['Price']>=85000)
Price_gt.reset_index()
# Out:
#        index           Sub                  Add  Rooms Type     Price Method  \
# 0       4100     Footscray     202/51 Gordon St    1.0    u   85000.0     PI
# 1       8867  Malvern East  114/141 Waverley Rd    1.0    u  112000.0      S
# 2      31660  Malvern East  114/141 Waverley Rd    1.0    u  112000.0      S
# 3      13611  Malvern East  114/141 Waverley Rd    1.0    u  112000.0      S
# 4      46453  Malvern East  114/141 Waverley Rd    1.0    u  112000.0      S
# ...      ...           ...                  ...    ...  ...       ...    ...
# 63018  63001           NaN                  NaN    NaN  NaN       NaN    NaN
# 63019  63008           NaN                  NaN    NaN  NaN       NaN    NaN
# 63020  63010           NaN                  NaN    NaN  NaN       NaN    NaN
# 63021  63021           NaN                  NaN    NaN  NaN       NaN    NaN
# 63022  63022           NaN                  NaN    NaN  NaN       NaN    NaN
#
# ...

# %%
import matplotlib.pyplot as plt
df[df["Type"] == "h"].groupby("Date")["Price"].sum().plot()
